# %%
import pandas as pd
import numpy as np

# %%
Health_Coverage = pd.read_csv("/Users/deannalakshman/Desktop/IIT/YEAR 2/SEM 2/DSPLC/Individual technical/Raw_Datasets/UHC_SCI_WIDEF (1).csv")
Financial_Hardships = pd.read_csv("/Users/deannalakshman/Desktop/IIT/YEAR 2/SEM 2/DSPLC/Individual technical/Raw_Datasets/UHC_FH40_WIDEF.csv")

# %%
print(Health_Coverage.head())
# Out:
#        STRUCTURE              STRUCTURE_ID ACTION FREQ REF_AREA INDICATOR  \
# 0  datastructure  WB.GGH.HNP:DS_UHC(1.1.0)      I    A      KHM   UHC_SCI
# 1  datastructure  WB.GGH.HNP:DS_UHC(1.1.0)      I    A      MHL   UHC_SCI
# 2  datastructure  WB.GGH.HNP:DS_UHC(1.1.0)      I    A      ESP   UHC_SCI
# 3  datastructure  WB.GGH.HNP:DS_UHC(1.1.0)      I    A      BOL   UHC_SCI
# 4  datastructure  WB.GGH.HNP:DS_UHC(1.1.0)      I    A      TUN   UHC_SCI
#
#   URBANIZATION HH_MAC IC_QUINTILE FINANCIAL_HARDSHIP  ...  2014  2015  2016  \
# 0           _Z     _Z          _Z                 _Z  ...  51.0  52.0  55.0
# 1           _Z     _Z          _Z                 _Z  ...  73.0  74.0  76.0
# 2           _Z     _Z          _Z                 _Z  ...  98.0  97.0  98.0
# 3           _Z     _Z          _Z                 _Z  ...  68.0  69.0  69.0
# 4           _Z     _Z          _Z                 _Z  ...  74.0  76.0  78.0
#
#    2017  2018  2019  2020  2021  2022  2023
# ...

# %%
print(Financial_Hardships.head())
# Out:
#        STRUCTURE              STRUCTURE_ID ACTION FREQ REF_AREA INDICATOR  \
# 0  datastructure  WB.GGH.HNP:DS_UHC(1.1.0)      I    A      DOM  UHC_FH40
# 1  datastructure  WB.GGH.HNP:DS_UHC(1.1.0)      I    A      SRB  UHC_FH40
# 2  datastructure  WB.GGH.HNP:DS_UHC(1.1.0)      I    A      GRC  UHC_FH40
# 3  datastructure  WB.GGH.HNP:DS_UHC(1.1.0)      I    A      DOM  UHC_FH40
# 4  datastructure  WB.GGH.HNP:DS_UHC(1.1.0)      I    A      PSE  UHC_FH40
#
#   URBANIZATION HH_MAC IC_QUINTILE FINANCIAL_HARDSHIP  ...  2015  2016  2017  \
# 0          URB     _T          _T             ALL_FH  ...   NaN   NaN   NaN
# 1           _T     _T          _T             PUSHED  ...  0.79  0.70  1.23
# 2           _T     _T          _T             PUSHED  ...  1.69  2.08  1.34
# 3           _T     _T       IC_Q1             ALL_FH  ...   NaN   NaN   NaN
# 4           _T     _T          _T              LARGE  ...   NaN  3.72   NaN
#
#     2018  2019  2020  2021  2022  2023 2024
# ...

# %%
print(Health_Coverage.shape)
# Out:
# (1035, 59)

# %%
print(Financial_Hardships.shape)
# Out:
# (2612, 74)

# %%
print(Health_Coverage.columns)
# Out:
# Index(['STRUCTURE', 'STRUCTURE_ID', 'ACTION', 'FREQ', 'REF_AREA', 'INDICATOR',
#        'URBANIZATION', 'HH_MAC', 'IC_QUINTILE', 'FINANCIAL_HARDSHIP',
#        'INDEX_COMP', 'SPEND_LEVEL', 'UNIT_MEASURE', 'OBS_CONF', 'UNIT_TYPE',
#        'DATABASE_ID', 'DECIMALS', 'UNIT_MULT', 'OBS_STATUS', 'FREQ_LABEL',
#        'REF_AREA_LABEL', 'INDICATOR_LABEL', 'URBANIZATION_LABEL',
#        'HH_MAC_LABEL', 'IC_QUINTILE_LABEL', 'FINANCIAL_HARDSHIP_LABEL',
#        'INDEX_COMP_LABEL', 'SPEND_LEVEL_LABEL', 'UNIT_MEASURE_LABEL',
#        'OBS_STATUS_LABEL', 'OBS_CONF_LABEL', 'UNIT_TYPE_LABEL',
#        'DATABASE_ID_LABEL', 'DECIMALS_LABEL', 'UNIT_MULT_LABEL', '2000',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020', '2021', '2022', '2023'],
#       dtype='object')

# %%
print(Financial_Hardships.columns)
# Out:
# Index(['STRUCTURE', 'STRUCTURE_ID', 'ACTION', 'FREQ', 'REF_AREA', 'INDICATOR',
#        'URBANIZATION', 'HH_MAC', 'IC_QUINTILE', 'FINANCIAL_HARDSHIP',
#        'INDEX_COMP', 'SPEND_LEVEL', 'UNIT_MEASURE', 'OBS_CONF', 'UNIT_TYPE',
#        'DATABASE_ID', 'DECIMALS', 'UNIT_MULT', 'OBS_STATUS', 'FREQ_LABEL',
#        'REF_AREA_LABEL', 'INDICATOR_LABEL', 'URBANIZATION_LABEL',
#        'HH_MAC_LABEL', 'IC_QUINTILE_LABEL', 'FINANCIAL_HARDSHIP_LABEL',
#        'INDEX_COMP_LABEL', 'SPEND_LEVEL_LABEL', 'UNIT_MEASURE_LABEL',
#        'OBS_STATUS_LABEL', 'OBS_CONF_LABEL', 'UNIT_TYPE_LABEL',
#        'DATABASE_ID_LABEL', 'DECIMALS_LABEL', 'UNIT_MULT_LABEL', '1985',
#        '1986', '1987', '1988', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
# ...

# %%
Health_Coverage.drop(columns=['STRUCTURE', 'STRUCTURE_ID', 'ACTION', 'FREQ', 'REF_AREA', 'INDICATOR',
       'URBANIZATION', 'HH_MAC', 'IC_QUINTILE', 'FINANCIAL_HARDSHIP',
       'INDEX_COMP', 'SPEND_LEVEL', 'UNIT_MEASURE', 'OBS_CONF', 'UNIT_TYPE',
       'DATABASE_ID', 'DECIMALS', 'UNIT_MULT', 'OBS_STATUS', 'FREQ_LABEL'])
